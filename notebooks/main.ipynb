# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
project_path = '/content/drive/MyDrive/dl_lecture_competition'
os.chdir(project_path)

# %%
# !pip3 install hydra-core --upgrade
# !pip3 install hdf5plugin
# Out:
# Requirement already satisfied: hydra-core in /opt/homebrew/lib/python3.11/site-packages (1.3.2)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /opt/homebrew/lib/python3.11/site-packages (from hydra-core) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /opt/homebrew/lib/python3.11/site-packages (from hydra-core) (4.9.3)
# Requirement already satisfied: packaging in /opt/homebrew/lib/python3.11/site-packages (from hydra-core) (23.2)
# Requirement already satisfied: PyYAML>=5.1.0 in /opt/homebrew/lib/python3.11/site-packages (from omegaconf<2.4,>=2.2->hydra-core) (6.0.1)
#
# [notice] A new release of pip is available: 24.1.1 -> 24.1.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Requirement already satisfied: hdf5plugin in /opt/homebrew/lib/python3.11/site-packages (4.4.0)
# Requirement already satisfied: h5py in /opt/homebrew/lib/python3.11/site-packages (from hdf5plugin) (3.11.0)
# Requirement already satisfied: numpy>=1.17.3 in /opt/homebrew/lib/python3.11/site-packages (from h5py->hdf5plugin) (1.26.1)
#
# [notice] A new release of pip is available: 24.1.1 -> 24.1.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
# !pip3 install -r ../requirements.txt
# Out:
# Requirement already satisfied: antlr4-python3-runtime==4.9.3 in /opt/homebrew/lib/python3.11/site-packages (from -r ../requirements.txt (line 1)) (4.9.3)
# Requirement already satisfied: cachetools==5.3.3 in /opt/homebrew/lib/python3.11/site-packages (from -r ../requirements.txt (line 2)) (5.3.3)
# Collecting colorama==0.4.6 (from -r ../requirements.txt (line 3))
#   Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting contourpy==1.2.1 (from -r ../requirements.txt (line 4))
#   Using cached contourpy-1.2.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Requirement already satisfied: cycler==0.12.1 in /opt/homebrew/lib/python3.11/site-packages (from -r ../requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: filelock==3.14.0 in /opt/homebrew/lib/python3.11/site-packages (from -r ../requirements.txt (line 6)) (3.14.0)
# Collecting fonttools==4.51.0 (from -r ../requirements.txt (line 7))
#   Using cached fonttools-4.51.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (159 kB)
# Requirement already satisfied: fsspec==2024.3.1 in /opt/homebrew/lib/python3.11/site-packages (from -r ../requirements.txt (line 8)) (2024.3.1)
# Collecting h5pickle==0.4.2 (from -r ../requirements.txt (line 9))
#   Using cached h5pickle-0.4.2-py3-none-any.whl.metadata (404 bytes)
# Requirement already satisfied: h5py==3.11.0 in /opt/homebrew/lib/python3.11/site-packages (from -r ../requirements.txt (line 10)) (3.11.0)
# Requirement already satisfied: hdf5plugin==4.4.0 in /opt/homebrew/lib/python3.11/site-packages (from -r ../requirements.txt (line 11)) (4.4.0)
# Requirement already satisfied: hydra-core==1.3.2 in /opt/homebrew/lib/python3.11/site-packages (from -r ../requirements.txt (line 12)) (1.3.2)
# Collecting imageio==2.34.1 (from -r ../requirements.txt (line 13))
#   Using cached imageio-2.34.1-py3-none-any.whl.metadata (4.9 kB)
# ERROR: Could not find a version that satisfies the requirement intel-openmp==2021.4.0 (from versions: none)
# ERROR: No matching distribution found for intel-openmp==2021.4.0
#
# [notice] A new release of pip is available: 24.1.1 -> 24.1.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
# %env HYDRA_FULL_ERROR=1
# !python3 ../main.py
# Out:
# env: HYDRA_FULL_ERROR=1
# Traceback (most recent call last):
#   File "/Users/josawashunsuke/Documents/dl_lecture_competition_pub/notebooks/../main.py", line 1, in <module>
#     import torch
# ModuleNotFoundError: No module named 'torch'
